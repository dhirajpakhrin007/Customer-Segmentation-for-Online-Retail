# %%
import pandas as pd

# %%
df = pd.read_excel("online_retail_II.xlsx")

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
data = df.to_dict(orient="records")

# %%
data
# Out:
# [{'Invoice': 489434,
#   'StockCode': 85048,
#   'Description': '15CM CHRISTMAS GLASS BALL 20 LIGHTS',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 07:45:00'),
#   'Price': 6.95,
#   'Customer ID': 13085.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489434,
#   'StockCode': '79323P',
#   'Description': 'PINK CHERRY LIGHTS',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 07:45:00'),
#   'Price': 6.75,
#   'Customer ID': 13085.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489434,
#   'StockCode': '79323W',
#   'Description': ' WHITE CHERRY LIGHTS',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 07:45:00'),
#   'Price': 6.75,
#   'Customer ID': 13085.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489434,
#   'StockCode': 22041,
#   'Description': 'RECORD FRAME 7" SINGLE SIZE ',
#   'Quantity': 48,
#   'InvoiceDate': Timestamp('2009-12-01 07:45:00'),
#   'Price': 2.1,
#   'Customer ID': 13085.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489434,
#   'StockCode': 21232,
#   'Description': 'STRAWBERRY CERAMIC TRINKET BOX',
#   'Quantity': 24,
#   'InvoiceDate': Timestamp('2009-12-01 07:45:00'),
#   'Price': 1.25,
#   'Customer ID': 13085.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489434,
#   'StockCode': 22064,
#   'Description': 'PINK DOUGHNUT TRINKET POT ',
#   'Quantity': 24,
#   'InvoiceDate': Timestamp('2009-12-01 07:45:00'),
#   'Price': 1.65,
#   'Customer ID': 13085.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489434,
#   'StockCode': 21871,
#   'Description': 'SAVE THE PLANET MUG',
#   'Quantity': 24,
#   'InvoiceDate': Timestamp('2009-12-01 07:45:00'),
#   'Price': 1.25,
#   'Customer ID': 13085.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489434,
#   'StockCode': 21523,
#   'Description': 'FANCY FONT HOME SWEET HOME DOORMAT',
#   'Quantity': 10,
#   'InvoiceDate': Timestamp('2009-12-01 07:45:00'),
#   'Price': 5.95,
#   'Customer ID': 13085.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489435,
#   'StockCode': 22350,
#   'Description': 'CAT BOWL ',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 07:46:00'),
#   'Price': 2.55,
#   'Customer ID': 13085.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489435,
#   'StockCode': 22349,
#   'Description': 'DOG BOWL , CHASING BALL DESIGN',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 07:46:00'),
#   'Price': 3.75,
#   'Customer ID': 13085.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489435,
#   'StockCode': 22195,
#   'Description': 'HEART MEASURING SPOONS LARGE',
#   'Quantity': 24,
#   'InvoiceDate': Timestamp('2009-12-01 07:46:00'),
#   'Price': 1.65,
#   'Customer ID': 13085.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489435,
#   'StockCode': 22353,
#   'Description': 'LUNCHBOX WITH CUTLERY FAIRY CAKES ',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 07:46:00'),
#   'Price': 2.55,
#   'Customer ID': 13085.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489436,
#   'StockCode': '48173C',
#   'Description': 'DOOR MAT BLACK FLOCK ',
#   'Quantity': 10,
#   'InvoiceDate': Timestamp('2009-12-01 09:06:00'),
#   'Price': 5.95,
#   'Customer ID': 13078.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489436,
#   'StockCode': 21755,
#   'Description': 'LOVE BUILDING BLOCK WORD',
#   'Quantity': 18,
#   'InvoiceDate': Timestamp('2009-12-01 09:06:00'),
#   'Price': 5.45,
#   'Customer ID': 13078.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489436,
#   'StockCode': 21754,
#   'Description': 'HOME BUILDING BLOCK WORD',
#   'Quantity': 3,
#   'InvoiceDate': Timestamp('2009-12-01 09:06:00'),
#   'Price': 5.95,
#   'Customer ID': 13078.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489436,
#   'StockCode': 84879,
#   'Description': 'ASSORTED COLOUR BIRD ORNAMENT',
#   'Quantity': 16,
#   'InvoiceDate': Timestamp('2009-12-01 09:06:00'),
#   'Price': 1.69,
#   'Customer ID': 13078.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489436,
#   'StockCode': 22119,
#   'Description': ' PEACE WOODEN BLOCK LETTERS',
#   'Quantity': 3,
#   'InvoiceDate': Timestamp('2009-12-01 09:06:00'),
#   'Price': 6.95,
#   'Customer ID': 13078.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489436,
#   'StockCode': 22142,
#   'Description': 'CHRISTMAS CRAFT WHITE FAIRY ',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:06:00'),
#   'Price': 1.45,
#   'Customer ID': 13078.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489436,
#   'StockCode': 22296,
#   'Description': 'HEART IVORY TRELLIS LARGE',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:06:00'),
#   'Price': 1.65,
#   'Customer ID': 13078.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489436,
#   'StockCode': 22295,
#   'Description': 'HEART FILIGREE DOVE LARGE',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:06:00'),
#   'Price': 1.65,
#   'Customer ID': 13078.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489436,
#   'StockCode': 22109,
#   'Description': 'FULL ENGLISH BREAKFAST PLATE',
#   'Quantity': 16,
#   'InvoiceDate': Timestamp('2009-12-01 09:06:00'),
#   'Price': 3.39,
#   'Customer ID': 13078.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489436,
#   'StockCode': 22107,
#   'Description': 'PIZZA PLATE IN BOX',
#   'Quantity': 4,
#   'InvoiceDate': Timestamp('2009-12-01 09:06:00'),
#   'Price': 3.75,
#   'Customer ID': 13078.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489436,
#   'StockCode': 22194,
#   'Description': 'BLACK DINER WALL CLOCK',
#   'Quantity': 2,
#   'InvoiceDate': Timestamp('2009-12-01 09:06:00'),
#   'Price': 8.5,
#   'Customer ID': 13078.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489436,
#   'StockCode': '35004B',
#   'Description': 'SET OF 3 BLACK FLYING DUCKS',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:06:00'),
#   'Price': 4.65,
#   'Customer ID': 13078.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489436,
#   'StockCode': 82582,
#   'Description': 'AREA PATROLLED METAL SIGN',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:06:00'),
#   'Price': 2.1,
#   'Customer ID': 13078.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489436,
#   'StockCode': 21181,
#   'Description': 'PLEASE ONE PERSON  METAL SIGN',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:06:00'),
#   'Price': 2.1,
#   'Customer ID': 13078.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489436,
#   'StockCode': 21756,
#   'Description': 'BATH BUILDING BLOCK WORD',
#   'Quantity': 3,
#   'InvoiceDate': Timestamp('2009-12-01 09:06:00'),
#   'Price': 5.95,
#   'Customer ID': 13078.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489436,
#   'StockCode': 21333,
#   'Description': 'CLASSIC WHITE FRAME',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 09:06:00'),
#   'Price': 2.95,
#   'Customer ID': 13078.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489436,
#   'StockCode': '84596F',
#   'Description': 'SMALL MARSHMALLOWS PINK BOWL',
#   'Quantity': 8,
#   'InvoiceDate': Timestamp('2009-12-01 09:06:00'),
#   'Price': 1.25,
#   'Customer ID': 13078.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489436,
#   'StockCode': '84596L',
#   'Description': 'BISCUITS SMALL BOWL LIGHT BLUE',
#   'Quantity': 8,
#   'InvoiceDate': Timestamp('2009-12-01 09:06:00'),
#   'Price': 1.25,
#   'Customer ID': 13078.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489436,
#   'StockCode': 22111,
#   'Description': 'SCOTTIE DOG HOT WATER BOTTLE',
#   'Quantity': 24,
#   'InvoiceDate': Timestamp('2009-12-01 09:06:00'),
#   'Price': 4.25,
#   'Customer ID': 13078.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489437,
#   'StockCode': 22143,
#   'Description': 'CHRISTMAS CRAFT HEART DECORATIONS',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 09:08:00'),
#   'Price': 2.1,
#   'Customer ID': 15362.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489437,
#   'StockCode': 22145,
#   'Description': 'CHRISTMAS CRAFT HEART STOCKING ',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 09:08:00'),
#   'Price': 2.1,
#   'Customer ID': 15362.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489437,
#   'StockCode': 22130,
#   'Description': 'PARTY CONE CHRISTMAS DECORATION ',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:08:00'),
#   'Price': 0.85,
#   'Customer ID': 15362.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489437,
#   'StockCode': 21364,
#   'Description': 'PEACE SMALL WOOD LETTERS',
#   'Quantity': 2,
#   'InvoiceDate': Timestamp('2009-12-01 09:08:00'),
#   'Price': 6.75,
#   'Customer ID': 15362.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489437,
#   'StockCode': 21360,
#   'Description': 'JOY LARGE WOOD LETTERS',
#   'Quantity': 1,
#   'InvoiceDate': Timestamp('2009-12-01 09:08:00'),
#   'Price': 9.95,
#   'Customer ID': 15362.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489437,
#   'StockCode': 21351,
#   'Description': 'CINAMMON & ORANGE WREATH',
#   'Quantity': 2,
#   'InvoiceDate': Timestamp('2009-12-01 09:08:00'),
#   'Price': 6.75,
#   'Customer ID': 15362.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489437,
#   'StockCode': 21352,
#   'Description': 'EUCALYPTUS & PINECONE  WREATH',
#   'Quantity': 2,
#   'InvoiceDate': Timestamp('2009-12-01 09:08:00'),
#   'Price': 6.75,
#   'Customer ID': 15362.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489437,
#   'StockCode': 35400,
#   'Description': 'WOODEN BOX ADVENT CALENDAR ',
#   'Quantity': 2,
#   'InvoiceDate': Timestamp('2009-12-01 09:08:00'),
#   'Price': 8.95,
#   'Customer ID': 15362.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489437,
#   'StockCode': 20695,
#   'Description': 'FLORAL BLUE MONSTER',
#   'Quantity': 3,
#   'InvoiceDate': Timestamp('2009-12-01 09:08:00'),
#   'Price': 4.25,
#   'Customer ID': 15362.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489437,
#   'StockCode': 37370,
#   'Description': 'RETRO COFFEE MUGS ASSORTED',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:08:00'),
#   'Price': 1.25,
#   'Customer ID': 15362.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489437,
#   'StockCode': 10002,
#   'Description': 'INFLATABLE POLITICAL GLOBE ',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:08:00'),
#   'Price': 0.85,
#   'Customer ID': 15362.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489437,
#   'StockCode': '84507B',
#   'Description': 'STRIPES DESIGN MONKEY DOLL',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 09:08:00'),
#   'Price': 2.55,
#   'Customer ID': 15362.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489437,
#   'StockCode': 20703,
#   'Description': 'BLUE PADDED SOFT MOBILE',
#   'Quantity': 3,
#   'InvoiceDate': Timestamp('2009-12-01 09:08:00'),
#   'Price': 4.25,
#   'Customer ID': 15362.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489437,
#   'StockCode': 21987,
#   'Description': 'PACK OF 6 SKULL PAPER CUPS',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:08:00'),
#   'Price': 0.65,
#   'Customer ID': 15362.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489437,
#   'StockCode': 21989,
#   'Description': 'PACK OF 20 SKULL PAPER NAPKINS',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:08:00'),
#   'Price': 0.85,
#   'Customer ID': 15362.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489437,
#   'StockCode': '84970S',
#   'Description': 'HANGING HEART ZINC T-LIGHT HOLDER',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:08:00'),
#   'Price': 0.85,
#   'Customer ID': 15362.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489437,
#   'StockCode': 20971,
#   'Description': 'PINK BLUE FELT CRAFT TRINKET BOX',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:08:00'),
#   'Price': 1.25,
#   'Customer ID': 15362.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489437,
#   'StockCode': 22271,
#   'Description': 'FELTCRAFT DOLL ROSIE',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 09:08:00'),
#   'Price': 2.95,
#   'Customer ID': 15362.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489437,
#   'StockCode': 22272,
#   'Description': 'FELTCRAFT DOLL MARIA',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 09:08:00'),
#   'Price': 2.95,
#   'Customer ID': 15362.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489437,
#   'StockCode': 22274,
#   'Description': 'FELTCRAFT DOLL EMILY',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 09:08:00'),
#   'Price': 2.95,
#   'Customer ID': 15362.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489437,
#   'StockCode': 21912,
#   'Description': 'VINTAGE SNAKES & LADDERS',
#   'Quantity': 4,
#   'InvoiceDate': Timestamp('2009-12-01 09:08:00'),
#   'Price': 3.75,
#   'Customer ID': 15362.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489437,
#   'StockCode': 22111,
#   'Description': 'SCOTTIE DOG HOT WATER BOTTLE',
#   'Quantity': 3,
#   'InvoiceDate': Timestamp('2009-12-01 09:08:00'),
#   'Price': 4.95,
#   'Customer ID': 15362.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489437,
#   'StockCode': 22112,
#   'Description': 'CHOCOLATE HOT WATER BOTTLE',
#   'Quantity': 3,
#   'InvoiceDate': Timestamp('2009-12-01 09:08:00'),
#   'Price': 4.95,
#   'Customer ID': 15362.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489438,
#   'StockCode': 21329,
#   'Description': 'DINOSAURS  WRITING SET ',
#   'Quantity': 28,
#   'InvoiceDate': Timestamp('2009-12-01 09:24:00'),
#   'Price': 0.98,
#   'Customer ID': 18102.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489438,
#   'StockCode': 21252,
#   'Description': 'SET OF MEADOW  FLOWER STICKERS',
#   'Quantity': 30,
#   'InvoiceDate': Timestamp('2009-12-01 09:24:00'),
#   'Price': 1.69,
#   'Customer ID': 18102.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489438,
#   'StockCode': 21100,
#   'Description': 'CHARLIE AND LOLA CHARLOTTE BAG',
#   'Quantity': 30,
#   'InvoiceDate': Timestamp('2009-12-01 09:24:00'),
#   'Price': 1.15,
#   'Customer ID': 18102.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489438,
#   'StockCode': 21033,
#   'Description': 'JUMBO BAG CHARLIE AND LOLA TOYS',
#   'Quantity': 30,
#   'InvoiceDate': Timestamp('2009-12-01 09:24:00'),
#   'Price': 2.0,
#   'Customer ID': 18102.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489438,
#   'StockCode': 20711,
#   'Description': 'JUMBO BAG TOYS ',
#   'Quantity': 60,
#   'InvoiceDate': Timestamp('2009-12-01 09:24:00'),
#   'Price': 1.3,
#   'Customer ID': 18102.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489438,
#   'StockCode': 21410,
#   'Description': 'COUNTRY COTTAGE  DOORSTOP GREEN',
#   'Quantity': 32,
#   'InvoiceDate': Timestamp('2009-12-01 09:24:00'),
#   'Price': 2.5,
#   'Customer ID': 18102.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489438,
#   'StockCode': 21411,
#   'Description': 'GINGHAM HEART  DOORSTOP RED',
#   'Quantity': 32,
#   'InvoiceDate': Timestamp('2009-12-01 09:24:00'),
#   'Price': 2.5,
#   'Customer ID': 18102.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489438,
#   'StockCode': '84031A',
#   'Description': 'CHARLIE+LOLA RED HOT WATER BOTTLE ',
#   'Quantity': 56,
#   'InvoiceDate': Timestamp('2009-12-01 09:24:00'),
#   'Price': 3.0,
#   'Customer ID': 18102.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489438,
#   'StockCode': '84031B',
#   'Description': 'CHARLIE LOLA BLUE HOT WATER BOTTLE ',
#   'Quantity': 56,
#   'InvoiceDate': Timestamp('2009-12-01 09:24:00'),
#   'Price': 3.0,
#   'Customer ID': 18102.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489438,
#   'StockCode': '84032A',
#   'Description': 'CHARLIE+LOLA PINK HOT WATER BOTTLE',
#   'Quantity': 60,
#   'InvoiceDate': Timestamp('2009-12-01 09:24:00'),
#   'Price': 1.9,
#   'Customer ID': 18102.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489438,
#   'StockCode': '84032B',
#   'Description': 'CHARLIE + LOLA RED HOT WATER BOTTLE',
#   'Quantity': 56,
#   'InvoiceDate': Timestamp('2009-12-01 09:24:00'),
#   'Price': 1.9,
#   'Customer ID': 18102.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489438,
#   'StockCode': '84519A',
#   'Description': 'TOMATO CHARLIE+LOLA COASTER SET',
#   'Quantity': 56,
#   'InvoiceDate': Timestamp('2009-12-01 09:24:00'),
#   'Price': 2.15,
#   'Customer ID': 18102.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489438,
#   'StockCode': '84519B',
#   'Description': 'CARROT CHARLIE+LOLA COASTER SET',
#   'Quantity': 60,
#   'InvoiceDate': Timestamp('2009-12-01 09:24:00'),
#   'Price': 2.4,
#   'Customer ID': 18102.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489438,
#   'StockCode': '85132A',
#   'Description': 'CHARLIE + LOLA BISCUITS TINS',
#   'Quantity': 60,
#   'InvoiceDate': Timestamp('2009-12-01 09:24:00'),
#   'Price': 6.38,
#   'Customer ID': 18102.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489438,
#   'StockCode': '85132C',
#   'Description': 'CHARLIE AND LOLA FIGURES TINS',
#   'Quantity': 60,
#   'InvoiceDate': Timestamp('2009-12-01 09:24:00'),
#   'Price': 6.4,
#   'Customer ID': 18102.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489438,
#   'StockCode': '85183A',
#   'Description': 'CHARLIE & LOLA WASTEPAPER BIN BLUE',
#   'Quantity': 60,
#   'InvoiceDate': Timestamp('2009-12-01 09:24:00'),
#   'Price': 2.4,
#   'Customer ID': 18102.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489438,
#   'StockCode': '85183B',
#   'Description': 'CHARLIE & LOLA WASTEPAPER BIN FLORA',
#   'Quantity': 60,
#   'InvoiceDate': Timestamp('2009-12-01 09:24:00'),
#   'Price': 2.4,
#   'Customer ID': 18102.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489439,
#   'StockCode': 22065,
#   'Description': 'CHRISTMAS PUDDING TRINKET POT ',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:28:00'),
#   'Price': 1.45,
#   'Customer ID': 12682.0,
#   'Country': 'France'},
#  {'Invoice': 489439,
#   'StockCode': 22138,
#   'Description': 'BAKING SET 9 PIECE RETROSPOT ',
#   'Quantity': 9,
#   'InvoiceDate': Timestamp('2009-12-01 09:28:00'),
#   'Price': 4.95,
#   'Customer ID': 12682.0,
#   'Country': 'France'},
#  {'Invoice': 489439,
#   'StockCode': 22139,
#   'Description': 'RETRO SPOT TEA SET CERAMIC 11 PC ',
#   'Quantity': 9,
#   'InvoiceDate': Timestamp('2009-12-01 09:28:00'),
#   'Price': 4.95,
#   'Customer ID': 12682.0,
#   'Country': 'France'},
#  {'Invoice': 489439,
#   'StockCode': 22352,
#   'Description': 'LUNCHBOX WITH CUTLERY RETROSPOT ',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:28:00'),
#   'Price': 2.55,
#   'Customer ID': 12682.0,
#   'Country': 'France'},
#  {'Invoice': 489439,
#   'StockCode': '85014A',
#   'Description': 'BLACK/BLUE DOTS RUFFLED UMBRELLA',
#   'Quantity': 3,
#   'InvoiceDate': Timestamp('2009-12-01 09:28:00'),
#   'Price': 5.95,
#   'Customer ID': 12682.0,
#   'Country': 'France'},
#  {'Invoice': 489439,
#   'StockCode': '85014B',
#   'Description': 'RED/WHITE DOTS RUFFLED UMBRELLA',
#   'Quantity': 3,
#   'InvoiceDate': Timestamp('2009-12-01 09:28:00'),
#   'Price': 5.95,
#   'Customer ID': 12682.0,
#   'Country': 'France'},
#  {'Invoice': 489439,
#   'StockCode': '16161P',
#   'Description': 'WRAP ENGLISH ROSE ',
#   'Quantity': 25,
#   'InvoiceDate': Timestamp('2009-12-01 09:28:00'),
#   'Price': 0.42,
#   'Customer ID': 12682.0,
#   'Country': 'France'},
#  {'Invoice': 489439,
#   'StockCode': '16169N',
#   'Description': 'WRAP BLUE RUSSIAN FOLKART',
#   'Quantity': 25,
#   'InvoiceDate': Timestamp('2009-12-01 09:28:00'),
#   'Price': 0.42,
#   'Customer ID': 12682.0,
#   'Country': 'France'},
#  {'Invoice': 489439,
#   'StockCode': 21491,
#   'Description': 'SET OF THREE VINTAGE GIFT WRAPS',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 09:28:00'),
#   'Price': 1.95,
#   'Customer ID': 12682.0,
#   'Country': 'France'},
#  {'Invoice': 489439,
#   'StockCode': 22333,
#   'Description': 'RETRO SPORT PARTY BAG + STICKER SET',
#   'Quantity': 8,
#   'InvoiceDate': Timestamp('2009-12-01 09:28:00'),
#   'Price': 1.65,
#   'Customer ID': 12682.0,
#   'Country': 'France'},
#  {'Invoice': 489439,
#   'StockCode': 85216,
#   'Description': 'ASSORTED CAKES FRIDGE MAGNETS',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:28:00'),
#   'Price': 0.65,
#   'Customer ID': 12682.0,
#   'Country': 'France'},
#  {'Invoice': 489439,
#   'StockCode': 21493,
#   'Description': ' VINTAGE DESIGN GIFT TAGS',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:28:00'),
#   'Price': 0.85,
#   'Customer ID': 12682.0,
#   'Country': 'France'},
#  {'Invoice': 489439,
#   'StockCode': 22130,
#   'Description': 'PARTY CONE CHRISTMAS DECORATION ',
#   'Quantity': 24,
#   'InvoiceDate': Timestamp('2009-12-01 09:28:00'),
#   'Price': 0.85,
#   'Customer ID': 12682.0,
#   'Country': 'France'},
#  {'Invoice': 489439,
#   'StockCode': 22064,
#   'Description': 'PINK DOUGHNUT TRINKET POT ',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:28:00'),
#   'Price': 1.65,
#   'Customer ID': 12682.0,
#   'Country': 'France'},
#  {'Invoice': 489439,
#   'StockCode': 21731,
#   'Description': 'RED TOADSTOOL LED NIGHT LIGHT',
#   'Quantity': 24,
#   'InvoiceDate': Timestamp('2009-12-01 09:28:00'),
#   'Price': 1.65,
#   'Customer ID': 12682.0,
#   'Country': 'France'},
#  {'Invoice': 489439,
#   'StockCode': '85232B',
#   'Description': 'SET/3 RUSSIAN DOLL STACKING TINS',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 09:28:00'),
#   'Price': 4.95,
#   'Customer ID': 12682.0,
#   'Country': 'France'},
#  {'Invoice': 489439,
#   'StockCode': 84691,
#   'Description': 'PACK 20 DOLLY PEGS',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:28:00'),
#   'Price': 0.85,
#   'Customer ID': 12682.0,
#   'Country': 'France'},
#  {'Invoice': 489439,
#   'StockCode': 20749,
#   'Description': 'ASSORTED COLOUR MINI CASES',
#   'Quantity': 2,
#   'InvoiceDate': Timestamp('2009-12-01 09:28:00'),
#   'Price': 7.95,
#   'Customer ID': 12682.0,
#   'Country': 'France'},
#  {'Invoice': 489439,
#   'StockCode': 'POST',
#   'Description': 'POSTAGE',
#   'Quantity': 3,
#   'InvoiceDate': Timestamp('2009-12-01 09:28:00'),
#   'Price': 18.0,
#   'Customer ID': 12682.0,
#   'Country': 'France'},
#  {'Invoice': 489440,
#   'StockCode': 22350,
#   'Description': 'CAT BOWL ',
#   'Quantity': 8,
#   'InvoiceDate': Timestamp('2009-12-01 09:43:00'),
#   'Price': 2.55,
#   'Customer ID': 18087.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489440,
#   'StockCode': 22349,
#   'Description': 'DOG BOWL , CHASING BALL DESIGN',
#   'Quantity': 8,
#   'InvoiceDate': Timestamp('2009-12-01 09:43:00'),
#   'Price': 3.75,
#   'Customer ID': 18087.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489441,
#   'StockCode': 22321,
#   'Description': 'BIRD DECORATION RED SPOT',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:44:00'),
#   'Price': 0.72,
#   'Customer ID': 18087.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489441,
#   'StockCode': 22138,
#   'Description': 'BAKING SET 9 PIECE RETROSPOT ',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 09:44:00'),
#   'Price': 4.25,
#   'Customer ID': 18087.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489441,
#   'StockCode': '84029E',
#   'Description': 'RED WOOLLY HOTTIE WHITE HEART.',
#   'Quantity': 36,
#   'InvoiceDate': Timestamp('2009-12-01 09:44:00'),
#   'Price': 2.95,
#   'Customer ID': 18087.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489441,
#   'StockCode': 22111,
#   'Description': 'SCOTTIE DOG HOT WATER BOTTLE',
#   'Quantity': 48,
#   'InvoiceDate': Timestamp('2009-12-01 09:44:00'),
#   'Price': 4.25,
#   'Customer ID': 18087.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489442,
#   'StockCode': 21955,
#   'Description': 'UNION JACK GUNS & ROSES  DOORMAT',
#   'Quantity': 2,
#   'InvoiceDate': Timestamp('2009-12-01 09:46:00'),
#   'Price': 6.75,
#   'Customer ID': 13635.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489442,
#   'StockCode': 22111,
#   'Description': 'SCOTTIE DOG HOT WATER BOTTLE',
#   'Quantity': 3,
#   'InvoiceDate': Timestamp('2009-12-01 09:46:00'),
#   'Price': 4.95,
#   'Customer ID': 13635.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489442,
#   'StockCode': 22296,
#   'Description': 'HEART IVORY TRELLIS LARGE',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:46:00'),
#   'Price': 1.65,
#   'Customer ID': 13635.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489442,
#   'StockCode': '84899E',
#   'Description': 'YELLOW + BROWN BEAR FELT PURSE KIT',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:46:00'),
#   'Price': 1.25,
#   'Customer ID': 13635.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489442,
#   'StockCode': 22271,
#   'Description': 'FELTCRAFT DOLL ROSIE',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 09:46:00'),
#   'Price': 2.95,
#   'Customer ID': 13635.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489442,
#   'StockCode': 22272,
#   'Description': 'FELTCRAFT DOLL MARIA',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 09:46:00'),
#   'Price': 2.95,
#   'Customer ID': 13635.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489442,
#   'StockCode': '85123A',
#   'Description': 'WHITE HANGING HEART T-LIGHT HOLDER',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 09:46:00'),
#   'Price': 2.95,
#   'Customer ID': 13635.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489442,
#   'StockCode': 21582,
#   'Description': 'KINGS CHOICE SMALL TUBE MATCHES',
#   'Quantity': 20,
#   'InvoiceDate': Timestamp('2009-12-01 09:46:00'),
#   'Price': 1.65,
#   'Customer ID': 13635.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489442,
#   'StockCode': 21586,
#   'Description': 'KINGS CHOICE GIANT TUBE MATCHES',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:46:00'),
#   'Price': 2.55,
#   'Customer ID': 13635.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489442,
#   'StockCode': 21590,
#   'Description': 'KINGS CHOICE CIGAR BOX MATCHES ',
#   'Quantity': 48,
#   'InvoiceDate': Timestamp('2009-12-01 09:46:00'),
#   'Price': 1.25,
#   'Customer ID': 13635.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489442,
#   'StockCode': 22091,
#   'Description': 'EMPIRE TISSUE BOX',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:46:00'),
#   'Price': 1.25,
#   'Customer ID': 13635.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489442,
#   'StockCode': '84251J',
#   'Description': 'GREETING CARD, THE BLACK CAT',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:46:00'),
#   'Price': 0.42,
#   'Customer ID': 13635.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489442,
#   'StockCode': 22024,
#   'Description': 'RAINY LADIES BIRTHDAY CARD',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:46:00'),
#   'Price': 0.42,
#   'Customer ID': 13635.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489442,
#   'StockCode': 22026,
#   'Description': 'BANQUET BIRTHDAY  CARD  ',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:46:00'),
#   'Price': 0.42,
#   'Customer ID': 13635.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489442,
#   'StockCode': 22029,
#   'Description': 'SPACE BOY BIRTHDAY CARD',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:46:00'),
#   'Price': 0.42,
#   'Customer ID': 13635.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489442,
#   'StockCode': 22025,
#   'Description': 'RING OF ROSES BIRTHDAY CARD',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:46:00'),
#   'Price': 0.42,
#   'Customer ID': 13635.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489442,
#   'StockCode': 22031,
#   'Description': 'BOTANICAL LAVENDER BIRTHDAY CARD',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:46:00'),
#   'Price': 0.42,
#   'Customer ID': 13635.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489442,
#   'StockCode': 21428,
#   'Description': 'SET3 BOOK BOX GREEN GINGHAM FLOWER ',
#   'Quantity': 4,
#   'InvoiceDate': Timestamp('2009-12-01 09:46:00'),
#   'Price': 4.25,
#   'Customer ID': 13635.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489442,
#   'StockCode': 21430,
#   'Description': 'SET/3 RED GINGHAM ROSE STORAGE BOX',
#   'Quantity': 4,
#   'InvoiceDate': Timestamp('2009-12-01 09:46:00'),
#   'Price': 3.75,
#   'Customer ID': 13635.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489442,
#   'StockCode': 21916,
#   'Description': 'SET 12 RETRO WHITE CHALK STICKS',
#   'Quantity': 24,
#   'InvoiceDate': Timestamp('2009-12-01 09:46:00'),
#   'Price': 0.42,
#   'Customer ID': 13635.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489442,
#   'StockCode': 21790,
#   'Description': 'VINTAGE SNAP CARDS',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:46:00'),
#   'Price': 0.85,
#   'Customer ID': 13635.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489442,
#   'StockCode': 21888,
#   'Description': 'BINGO SET',
#   'Quantity': 8,
#   'InvoiceDate': Timestamp('2009-12-01 09:46:00'),
#   'Price': 3.75,
#   'Customer ID': 13635.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489442,
#   'StockCode': 85178,
#   'Description': 'VICTORIAN SEWING KIT',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:46:00'),
#   'Price': 1.25,
#   'Customer ID': 13635.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489443,
#   'StockCode': 20754,
#   'Description': 'RETRO RED SPOTTY WASHING UP GLOVES',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 09:50:00'),
#   'Price': 2.1,
#   'Customer ID': 14110.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489443,
#   'StockCode': 21035,
#   'Description': 'SET/2 RED SPOTTY TEA TOWELS ',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:50:00'),
#   'Price': 2.95,
#   'Customer ID': 14110.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489443,
#   'StockCode': 22041,
#   'Description': 'RECORD FRAME 7" SINGLE SIZE ',
#   'Quantity': 48,
#   'InvoiceDate': Timestamp('2009-12-01 09:50:00'),
#   'Price': 2.1,
#   'Customer ID': 14110.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489443,
#   'StockCode': '82001S',
#   'Description': 'VINYL RECORD FRAME SILVER',
#   'Quantity': 24,
#   'InvoiceDate': Timestamp('2009-12-01 09:50:00'),
#   'Price': 3.39,
#   'Customer ID': 14110.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489443,
#   'StockCode': 82580,
#   'Description': 'BATHROOM METAL SIGN',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:50:00'),
#   'Price': 0.55,
#   'Customer ID': 14110.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489443,
#   'StockCode': 85150,
#   'Description': 'LADIES & GENTLEMEN METAL SIGN',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:50:00'),
#   'Price': 2.55,
#   'Customer ID': 14110.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489443,
#   'StockCode': 21041,
#   'Description': 'RED SPOTTY OVEN GLOVE DOUBLE',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 09:50:00'),
#   'Price': 2.95,
#   'Customer ID': 14110.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489444,
#   'StockCode': 'POST',
#   'Description': 'POSTAGE',
#   'Quantity': 1,
#   'InvoiceDate': Timestamp('2009-12-01 09:55:00'),
#   'Price': 141.0,
#   'Customer ID': 12636.0,
#   'Country': 'USA'},
#  {'Invoice': 489445,
#   'StockCode': '35916C',
#   'Description': 'PINK FELT HANGING HEART W FLOWER',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:57:00'),
#   'Price': 0.85,
#   'Customer ID': 17519.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489445,
#   'StockCode': '35916B',
#   'Description': 'BLUE FELT HANGING HEART W FLOWER',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:57:00'),
#   'Price': 0.85,
#   'Customer ID': 17519.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489445,
#   'StockCode': 22321,
#   'Description': 'BIRD DECORATION RED SPOT',
#   'Quantity': 24,
#   'InvoiceDate': Timestamp('2009-12-01 09:57:00'),
#   'Price': 0.85,
#   'Customer ID': 17519.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489445,
#   'StockCode': 22130,
#   'Description': 'PARTY CONE CHRISTMAS DECORATION ',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:57:00'),
#   'Price': 0.85,
#   'Customer ID': 17519.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489445,
#   'StockCode': 22180,
#   'Description': 'RETRO SPOT LAMP',
#   'Quantity': 2,
#   'InvoiceDate': Timestamp('2009-12-01 09:57:00'),
#   'Price': 9.95,
#   'Customer ID': 17519.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489445,
#   'StockCode': 22128,
#   'Description': 'PARTY CONES CANDY ASSORTED',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:57:00'),
#   'Price': 1.25,
#   'Customer ID': 17519.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489445,
#   'StockCode': 22163,
#   'Description': 'HEART STRING MEMO HOLDER HANGING',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 09:57:00'),
#   'Price': 2.95,
#   'Customer ID': 17519.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489445,
#   'StockCode': 35951,
#   'Description': 'FOLKART BAUBLE CHRISTMAS DECORATION',
#   'Quantity': 48,
#   'InvoiceDate': Timestamp('2009-12-01 09:57:00'),
#   'Price': 0.38,
#   'Customer ID': 17519.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489445,
#   'StockCode': 22253,
#   'Description': '6 CROCHET STRAWBERRIES',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:57:00'),
#   'Price': 1.25,
#   'Customer ID': 17519.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489445,
#   'StockCode': 84988,
#   'Description': 'SET OF 72 PINK HEART PAPER DOILIES',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:57:00'),
#   'Price': 1.45,
#   'Customer ID': 17519.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489445,
#   'StockCode': 22219,
#   'Description': 'LOVEBIRD HANGING DECORATION WHITE ',
#   'Quantity': 24,
#   'InvoiceDate': Timestamp('2009-12-01 09:57:00'),
#   'Price': 0.85,
#   'Customer ID': 17519.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489445,
#   'StockCode': '18097C',
#   'Description': 'WHITE TALL PORCELAIN T-LIGHT HOLDER',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 09:57:00'),
#   'Price': 2.55,
#   'Customer ID': 17519.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489445,
#   'StockCode': 22138,
#   'Description': 'BAKING SET 9 PIECE RETROSPOT ',
#   'Quantity': 3,
#   'InvoiceDate': Timestamp('2009-12-01 09:57:00'),
#   'Price': 4.95,
#   'Customer ID': 17519.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489445,
#   'StockCode': 21299,
#   'Description': 'EDWARDIAN TOILET ROLL UNIT ',
#   'Quantity': 1,
#   'InvoiceDate': Timestamp('2009-12-01 09:57:00'),
#   'Price': 12.75,
#   'Customer ID': 17519.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489445,
#   'StockCode': 21099,
#   'Description': 'SET/6 STRAWBERRY PAPER CUPS',
#   'Quantity': 24,
#   'InvoiceDate': Timestamp('2009-12-01 09:57:00'),
#   'Price': 0.65,
#   'Customer ID': 17519.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489445,
#   'StockCode': 21085,
#   'Description': 'SET/6 WOODLAND PAPER CUPS',
#   'Quantity': 24,
#   'InvoiceDate': Timestamp('2009-12-01 09:57:00'),
#   'Price': 0.65,
#   'Customer ID': 17519.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489445,
#   'StockCode': 21929,
#   'Description': 'JUMBO BAG PINK VINTAGE PAISLEY',
#   'Quantity': 10,
#   'InvoiceDate': Timestamp('2009-12-01 09:57:00'),
#   'Price': 1.95,
#   'Customer ID': 17519.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489445,
#   'StockCode': 22241,
#   'Description': 'GARLAND , WOODEN  " HAPPY EASTER"',
#   'Quantity': 24,
#   'InvoiceDate': Timestamp('2009-12-01 09:57:00'),
#   'Price': 1.25,
#   'Customer ID': 17519.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489445,
#   'StockCode': 21091,
#   'Description': 'SET/6 WOODLAND PAPER PLATES',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 09:57:00'),
#   'Price': 0.85,
#   'Customer ID': 17519.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 21733,
#   'Description': 'RED HANGING HEART T-LIGHT HOLDER',
#   'Quantity': 32,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 2.55,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': '85123A',
#   'Description': 'WHITE HANGING HEART T-LIGHT HOLDER',
#   'Quantity': 32,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 2.55,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 22178,
#   'Description': 'VICTORIAN GLASS HANGING T-LIGHT',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 1.25,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 22125,
#   'Description': 'UNION JACK HOT WATER BOTTLE ',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 5.95,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 21671,
#   'Description': 'RED SPOT CERAMIC DRAWER KNOB',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 1.25,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 22086,
#   'Description': "PAPER CHAIN KIT 50'S CHRISTMAS ",
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 2.95,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 22111,
#   'Description': 'SCOTTIE DOG HOT WATER BOTTLE',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 4.95,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 22112,
#   'Description': 'CHOCOLATE HOT WATER BOTTLE',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 4.95,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 22294,
#   'Description': 'HEART FILIGREE DOVE  SMALL',
#   'Quantity': 24,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 1.25,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 22199,
#   'Description': 'FRYING PAN RED POLKADOT ',
#   'Quantity': 4,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 4.25,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 22083,
#   'Description': 'PAPER CHAIN KIT RETRO SPOT',
#   'Quantity': 24,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 2.95,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 22114,
#   'Description': 'HOT WATER BOTTLE TEA AND SYMPATHY',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 3.95,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 21485,
#   'Description': 'RED SPOT HEART HOT WATER BOTTLE',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 4.95,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 21928,
#   'Description': 'JUMBO BAG SCANDINAVIAN PAISLEY',
#   'Quantity': 10,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 1.95,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 21929,
#   'Description': 'JUMBO BAG PINK VINTAGE PAISLEY',
#   'Quantity': 10,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 1.95,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': '85099B',
#   'Description': 'JUMBO BAG RED WHITE SPOTTY ',
#   'Quantity': 20,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 1.95,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 22356,
#   'Description': 'CHARLOTTE BAG , PINK/WHITE SPOTS',
#   'Quantity': 10,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 0.85,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 20724,
#   'Description': 'RED SPOTTY CHARLOTTE BAG',
#   'Quantity': 10,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 0.85,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 21590,
#   'Description': 'KINGS CHOICE CIGAR BOX MATCHES ',
#   'Quantity': 24,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 1.25,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 21592,
#   'Description': 'RETRO SPOT  CIGAR BOX MATCHES ',
#   'Quantity': 24,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 1.25,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 20725,
#   'Description': 'LUNCH BAG RED SPOTTY',
#   'Quantity': 10,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 1.65,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 20728,
#   'Description': 'LUNCH BAG CARS BLUE',
#   'Quantity': 10,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 1.65,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 20726,
#   'Description': 'LUNCH BAG WOODLAND',
#   'Quantity': 10,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 1.65,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 20754,
#   'Description': 'RETRO RED SPOTTY WASHING UP GLOVES',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 2.1,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 21217,
#   'Description': 'RED SPOTTY ROUND CAKE TINS',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 8.95,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 22195,
#   'Description': 'LARGE HEART MEASURING SPOONS',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 1.65,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489446,
#   'StockCode': 85066,
#   'Description': 'CREAM SWEETHEART MINI CHEST',
#   'Quantity': 2,
#   'InvoiceDate': Timestamp('2009-12-01 10:06:00'),
#   'Price': 12.75,
#   'Customer ID': 13758.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489447,
#   'StockCode': 'POST',
#   'Description': 'POSTAGE',
#   'Quantity': 1,
#   'InvoiceDate': Timestamp('2009-12-01 10:10:00'),
#   'Price': 130.0,
#   'Customer ID': 12362.0,
#   'Country': 'Belgium'},
#  {'Invoice': 489448,
#   'StockCode': 20827,
#   'Description': 'GOLD APERITIF GLASS',
#   'Quantity': 48,
#   'InvoiceDate': Timestamp('2009-12-01 10:18:00'),
#   'Price': 2.12,
#   'Customer ID': 15413.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489448,
#   'StockCode': 20825,
#   'Description': 'GOLD WINE GLASS',
#   'Quantity': 48,
#   'InvoiceDate': Timestamp('2009-12-01 10:18:00'),
#   'Price': 3.39,
#   'Customer ID': 15413.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489448,
#   'StockCode': 20823,
#   'Description': 'GOLD WINE GOBLET',
#   'Quantity': 48,
#   'InvoiceDate': Timestamp('2009-12-01 10:18:00'),
#   'Price': 4.25,
#   'Customer ID': 15413.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489448,
#   'StockCode': 20826,
#   'Description': 'SILVER APERITIF GLASS',
#   'Quantity': 48,
#   'InvoiceDate': Timestamp('2009-12-01 10:18:00'),
#   'Price': 2.12,
#   'Customer ID': 15413.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 'C489449',
#   'StockCode': 22087,
#   'Description': 'PAPER BUNTING WHITE LACE',
#   'Quantity': -12,
#   'InvoiceDate': Timestamp('2009-12-01 10:33:00'),
#   'Price': 2.95,
#   'Customer ID': 16321.0,
#   'Country': 'Australia'},
#  {'Invoice': 'C489449',
#   'StockCode': '85206A',
#   'Description': 'CREAM FELT EASTER EGG BASKET',
#   'Quantity': -6,
#   'InvoiceDate': Timestamp('2009-12-01 10:33:00'),
#   'Price': 1.65,
#   'Customer ID': 16321.0,
#   'Country': 'Australia'},
#  {'Invoice': 'C489449',
#   'StockCode': 21895,
#   'Description': "POTTING SHED SOW 'N' GROW SET",
#   'Quantity': -4,
#   'InvoiceDate': Timestamp('2009-12-01 10:33:00'),
#   'Price': 4.25,
#   'Customer ID': 16321.0,
#   'Country': 'Australia'},
#  {'Invoice': 'C489449',
#   'StockCode': 21896,
#   'Description': 'POTTING SHED TWINE',
#   'Quantity': -6,
#   'InvoiceDate': Timestamp('2009-12-01 10:33:00'),
#   'Price': 2.1,
#   'Customer ID': 16321.0,
#   'Country': 'Australia'},
#  {'Invoice': 'C489449',
#   'StockCode': 22083,
#   'Description': 'PAPER CHAIN KIT RETRO SPOT',
#   'Quantity': -12,
#   'InvoiceDate': Timestamp('2009-12-01 10:33:00'),
#   'Price': 2.95,
#   'Customer ID': 16321.0,
#   'Country': 'Australia'},
#  {'Invoice': 'C489449',
#   'StockCode': 21871,
#   'Description': 'SAVE THE PLANET MUG',
#   'Quantity': -12,
#   'InvoiceDate': Timestamp('2009-12-01 10:33:00'),
#   'Price': 1.25,
#   'Customer ID': 16321.0,
#   'Country': 'Australia'},
#  {'Invoice': 'C489449',
#   'StockCode': 84946,
#   'Description': 'ANTIQUE SILVER TEA GLASS ETCHED',
#   'Quantity': -12,
#   'InvoiceDate': Timestamp('2009-12-01 10:33:00'),
#   'Price': 1.25,
#   'Customer ID': 16321.0,
#   'Country': 'Australia'},
#  {'Invoice': 'C489449',
#   'StockCode': '84970S',
#   'Description': 'HANGING HEART ZINC T-LIGHT HOLDER',
#   'Quantity': -24,
#   'InvoiceDate': Timestamp('2009-12-01 10:33:00'),
#   'Price': 0.85,
#   'Customer ID': 16321.0,
#   'Country': 'Australia'},
#  {'Invoice': 'C489449',
#   'StockCode': 22090,
#   'Description': 'PAPER BUNTING RETRO SPOTS',
#   'Quantity': -12,
#   'InvoiceDate': Timestamp('2009-12-01 10:33:00'),
#   'Price': 2.95,
#   'Customer ID': 16321.0,
#   'Country': 'Australia'},
#  {'Invoice': 489450,
#   'StockCode': 22087,
#   'Description': 'PAPER BUNTING WHITE LACE',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 10:36:00'),
#   'Price': 2.95,
#   'Customer ID': 16321.0,
#   'Country': 'Australia'},
#  {'Invoice': 489450,
#   'StockCode': '85206A',
#   'Description': 'CREAM FELT EASTER EGG BASKET',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 10:36:00'),
#   'Price': 1.65,
#   'Customer ID': 16321.0,
#   'Country': 'Australia'},
#  {'Invoice': 489450,
#   'StockCode': 21895,
#   'Description': "POTTING SHED SOW 'N' GROW SET",
#   'Quantity': 4,
#   'InvoiceDate': Timestamp('2009-12-01 10:36:00'),
#   'Price': 4.25,
#   'Customer ID': 16321.0,
#   'Country': 'Australia'},
#  {'Invoice': 489450,
#   'StockCode': 21896,
#   'Description': 'POTTING SHED TWINE',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 10:36:00'),
#   'Price': 2.1,
#   'Customer ID': 16321.0,
#   'Country': 'Australia'},
#  {'Invoice': 489450,
#   'StockCode': 22083,
#   'Description': 'PAPER CHAIN KIT RETRO SPOT',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 10:36:00'),
#   'Price': 2.95,
#   'Customer ID': 16321.0,
#   'Country': 'Australia'},
#  {'Invoice': 489450,
#   'StockCode': 21871,
#   'Description': 'SAVE THE PLANET MUG',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 10:36:00'),
#   'Price': 1.25,
#   'Customer ID': 16321.0,
#   'Country': 'Australia'},
#  {'Invoice': 489450,
#   'StockCode': 84946,
#   'Description': 'ANTIQUE SILVER TEA GLASS ETCHED',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 10:36:00'),
#   'Price': 1.25,
#   'Customer ID': 16321.0,
#   'Country': 'Australia'},
#  {'Invoice': 489450,
#   'StockCode': '84970S',
#   'Description': 'HANGING HEART ZINC T-LIGHT HOLDER',
#   'Quantity': 24,
#   'InvoiceDate': Timestamp('2009-12-01 10:36:00'),
#   'Price': 0.85,
#   'Customer ID': 16321.0,
#   'Country': 'Australia'},
#  {'Invoice': 489450,
#   'StockCode': 22090,
#   'Description': 'PAPER BUNTING RETRO SPOTS',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 10:36:00'),
#   'Price': 2.95,
#   'Customer ID': 16321.0,
#   'Country': 'Australia'},
#  {'Invoice': 'C489459',
#   'StockCode': '90200A',
#   'Description': 'PURPLE SWEETHEART BRACELET',
#   'Quantity': -3,
#   'InvoiceDate': Timestamp('2009-12-01 10:44:00'),
#   'Price': 4.25,
#   'Customer ID': 17592.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 'C489459',
#   'StockCode': '90200D',
#   'Description': 'PINK SWEETHEART BRACELET',
#   'Quantity': -3,
#   'InvoiceDate': Timestamp('2009-12-01 10:44:00'),
#   'Price': 4.25,
#   'Customer ID': 17592.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 'C489459',
#   'StockCode': '90200B',
#   'Description': 'BLACK SWEETHEART BRACELET',
#   'Quantity': -3,
#   'InvoiceDate': Timestamp('2009-12-01 10:44:00'),
#   'Price': 4.25,
#   'Customer ID': 17592.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 'C489459',
#   'StockCode': '90200E',
#   'Description': 'GREEN SWEETHEART BRACELET',
#   'Quantity': -3,
#   'InvoiceDate': Timestamp('2009-12-01 10:44:00'),
#   'Price': 4.25,
#   'Customer ID': 17592.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 'C489459',
#   'StockCode': '90200C',
#   'Description': 'BLUE SWEETHEART BRACELET',
#   'Quantity': -3,
#   'InvoiceDate': Timestamp('2009-12-01 10:44:00'),
#   'Price': 4.25,
#   'Customer ID': 17592.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 'C489459',
#   'StockCode': '90185C',
#   'Description': 'BLACK DIAMANTE EXPANDABLE RING',
#   'Quantity': -3,
#   'InvoiceDate': Timestamp('2009-12-01 10:44:00'),
#   'Price': 4.25,
#   'Customer ID': 17592.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 'C489459',
#   'StockCode': '90185B',
#   'Description': 'AMETHYST DIAMANTE EXPANDABLE RING',
#   'Quantity': -3,
#   'InvoiceDate': Timestamp('2009-12-01 10:44:00'),
#   'Price': 4.25,
#   'Customer ID': 17592.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 'C489459',
#   'StockCode': '90003C',
#   'Description': 'MIDNIGHT BLUE PAIR HEART HAIR SLIDE',
#   'Quantity': -3,
#   'InvoiceDate': Timestamp('2009-12-01 10:44:00'),
#   'Price': 3.75,
#   'Customer ID': 17592.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 'C489459',
#   'StockCode': '90003D',
#   'Description': 'CRYSTAL PAIR HEART HAIR SLIDES',
#   'Quantity': -3,
#   'InvoiceDate': Timestamp('2009-12-01 10:44:00'),
#   'Price': 3.75,
#   'Customer ID': 17592.0,
#   'Country': 'United Kingdom'},
# ...
#  {'Invoice': 489540,
#   'StockCode': 84946,
#   'Description': 'ANTIQUE SILVER TEA GLASS ETCHED',
#   'Quantity': 24,
#   'InvoiceDate': Timestamp('2009-12-01 12:18:00'),
#   'Price': 1.25,
#   'Customer ID': 12913.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 'C489541',
#   'StockCode': 21254,
#   'Description': 'SET OF KITCHEN WALL  STICKERS',
#   'Quantity': -4,
#   'InvoiceDate': Timestamp('2009-12-01 12:18:00'),
#   'Price': 2.95,
#   'Customer ID': 15091.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489539,
#   'StockCode': 22086,
#   'Description': "PAPER CHAIN KIT 50'S CHRISTMAS ",
#   'Quantity': 160,
#   'InvoiceDate': Timestamp('2009-12-01 12:18:00'),
#   'Price': 2.55,
#   'Customer ID': 15061.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489539,
#   'StockCode': 22083,
#   'Description': 'PAPER CHAIN KIT RETRO SPOT',
#   'Quantity': 160,
#   'InvoiceDate': Timestamp('2009-12-01 12:18:00'),
#   'Price': 2.55,
#   'Customer ID': 15061.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489539,
#   'StockCode': 85041,
#   'Description': 'SET/4 PINK ORCHID CANDLES IN BOWL',
#   'Quantity': 48,
#   'InvoiceDate': Timestamp('2009-12-01 12:18:00'),
#   'Price': 1.45,
#   'Customer ID': 15061.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489539,
#   'StockCode': '85040B',
#   'Description': 'SET/4 BLUE FLOWER CANDLES IN BOWL',
#   'Quantity': 192,
#   'InvoiceDate': Timestamp('2009-12-01 12:18:00'),
#   'Price': 1.45,
#   'Customer ID': 15061.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489539,
#   'StockCode': 84879,
#   'Description': 'ASSORTED COLOUR BIRD ORNAMENT',
#   'Quantity': 96,
#   'InvoiceDate': Timestamp('2009-12-01 12:18:00'),
#   'Price': 1.69,
#   'Customer ID': 15061.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489539,
#   'StockCode': '79323P',
#   'Description': 'PINK CHERRY LIGHTS',
#   'Quantity': 24,
#   'InvoiceDate': Timestamp('2009-12-01 12:18:00'),
#   'Price': 5.45,
#   'Customer ID': 15061.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489539,
#   'StockCode': 48184,
#   'Description': 'DOOR MAT ENGLISH ROSE ',
#   'Quantity': 20,
#   'InvoiceDate': Timestamp('2009-12-01 12:18:00'),
#   'Price': 5.95,
#   'Customer ID': 15061.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489539,
#   'StockCode': 37461,
#   'Description': 'FUNKY MONKEY MUG',
#   'Quantity': 96,
#   'InvoiceDate': Timestamp('2009-12-01 12:18:00'),
#   'Price': 0.85,
#   'Customer ID': 15061.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489539,
#   'StockCode': 22139,
#   'Description': 'RETRO SPOT TEA SET CERAMIC 11 PC ',
#   'Quantity': 72,
#   'InvoiceDate': Timestamp('2009-12-01 12:18:00'),
#   'Price': 4.25,
#   'Customer ID': 15061.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489539,
#   'StockCode': 21700,
#   'Description': 'BIG DOUGHNUT FRIDGE MAGNETS',
#   'Quantity': 144,
#   'InvoiceDate': Timestamp('2009-12-01 12:18:00'),
#   'Price': 0.85,
#   'Customer ID': 15061.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489539,
#   'StockCode': 21673,
#   'Description': 'WHITE SPOT BLUE CERAMIC DRAWER KNOB',
#   'Quantity': 60,
#   'InvoiceDate': Timestamp('2009-12-01 12:18:00'),
#   'Price': 1.06,
#   'Customer ID': 15061.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489539,
#   'StockCode': 21671,
#   'Description': 'RED SPOT CERAMIC DRAWER KNOB',
#   'Quantity': 60,
#   'InvoiceDate': Timestamp('2009-12-01 12:18:00'),
#   'Price': 1.06,
#   'Customer ID': 15061.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489539,
#   'StockCode': 21669,
#   'Description': 'BLUE STRIPE CERAMIC DRAWER KNOB',
#   'Quantity': 60,
#   'InvoiceDate': Timestamp('2009-12-01 12:18:00'),
#   'Price': 1.06,
#   'Customer ID': 15061.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489539,
#   'StockCode': 21500,
#   'Description': 'PINK SPOTS  WRAP ',
#   'Quantity': 100,
#   'InvoiceDate': Timestamp('2009-12-01 12:18:00'),
#   'Price': 0.34,
#   'Customer ID': 15061.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489539,
#   'StockCode': 20692,
#   'Description': 'FLORAL ELEPHANT SOFT TOY',
#   'Quantity': 96,
#   'InvoiceDate': Timestamp('2009-12-01 12:18:00'),
#   'Price': 3.75,
#   'Customer ID': 15061.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489539,
#   'StockCode': 20685,
#   'Description': 'RED SPOTTY COIR DOORMAT',
#   'Quantity': 30,
#   'InvoiceDate': Timestamp('2009-12-01 12:18:00'),
#   'Price': 5.95,
#   'Customer ID': 15061.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489539,
#   'StockCode': 16237,
#   'Description': 'SLEEPING CAT ERASERS',
#   'Quantity': 180,
#   'InvoiceDate': Timestamp('2009-12-01 12:18:00'),
#   'Price': 0.21,
#   'Customer ID': 15061.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489542,
#   'StockCode': 37410,
#   'Description': 'BLACK AND WHITE PAISLEY FLOWER MUG',
#   'Quantity': 216,
#   'InvoiceDate': Timestamp('2009-12-01 12:19:00'),
#   'Price': 0.85,
#   'Customer ID': 15061.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489542,
#   'StockCode': 22139,
#   'Description': 'RETRO SPOT TEA SET CERAMIC 11 PC ',
#   'Quantity': 48,
#   'InvoiceDate': Timestamp('2009-12-01 12:19:00'),
#   'Price': 4.25,
#   'Customer ID': 15061.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 'C489543',
#   'StockCode': 35400,
#   'Description': 'WOODEN BOX ADVENT CALENDAR ',
#   'Quantity': -2,
#   'InvoiceDate': Timestamp('2009-12-01 12:19:00'),
#   'Price': 8.95,
#   'Customer ID': 14292.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489544,
#   'StockCode': 22086,
#   'Description': "PAPER CHAIN KIT 50'S CHRISTMAS ",
#   'Quantity': 18,
#   'InvoiceDate': Timestamp('2009-12-01 12:20:00'),
#   'Price': 2.95,
#   'Customer ID': 14341.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489544,
#   'StockCode': 84347,
#   'Description': 'ROTATING SILVER ANGELS T-LIGHT HLDR',
#   'Quantity': 18,
#   'InvoiceDate': Timestamp('2009-12-01 12:20:00'),
#   'Price': 2.55,
#   'Customer ID': 14341.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489544,
#   'StockCode': 22065,
#   'Description': 'CHRISTMAS PUDDING TRINKET POT ',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 12:20:00'),
#   'Price': 1.45,
#   'Customer ID': 14341.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489544,
#   'StockCode': 21813,
#   'Description': 'GARLAND WITH STARS AND BELLS',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 12:20:00'),
#   'Price': 4.95,
#   'Customer ID': 14341.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489544,
#   'StockCode': '84251F',
#   'Description': 'GREETING CARD, RITA',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 12:20:00'),
#   'Price': 0.19,
#   'Customer ID': 14341.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489544,
#   'StockCode': 20975,
#   'Description': '12 PENCILS SMALL TUBE RED SPOTTY',
#   'Quantity': 24,
#   'InvoiceDate': Timestamp('2009-12-01 12:20:00'),
#   'Price': 0.65,
#   'Customer ID': 14341.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489544,
#   'StockCode': 21080,
#   'Description': 'SET/20 RED SPOTTY PAPER NAPKINS ',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 12:20:00'),
#   'Price': 0.85,
#   'Customer ID': 14341.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489544,
#   'StockCode': 21844,
#   'Description': 'RETRO SPOT MUG',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 12:20:00'),
#   'Price': 2.95,
#   'Customer ID': 14341.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489544,
#   'StockCode': 22070,
#   'Description': 'SMALL RETRO SPOT MUG IN BOX  RED',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 12:20:00'),
#   'Price': 3.75,
#   'Customer ID': 14341.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489544,
#   'StockCode': 21980,
#   'Description': 'PACK OF 12 RED SPOTTY TISSUES ',
#   'Quantity': 48,
#   'InvoiceDate': Timestamp('2009-12-01 12:20:00'),
#   'Price': 0.29,
#   'Customer ID': 14341.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489544,
#   'StockCode': 21967,
#   'Description': 'PACK OF 12 SKULL TISSUES',
#   'Quantity': 48,
#   'InvoiceDate': Timestamp('2009-12-01 12:20:00'),
#   'Price': 0.29,
#   'Customer ID': 14341.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489544,
#   'StockCode': 22125,
#   'Description': 'UNION JACK HOT WATER BOTTLE ',
#   'Quantity': 3,
#   'InvoiceDate': Timestamp('2009-12-01 12:20:00'),
#   'Price': 5.95,
#   'Customer ID': 14341.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489544,
#   'StockCode': 21364,
#   'Description': 'PEACE SMALL WOOD LETTERS',
#   'Quantity': 1,
#   'InvoiceDate': Timestamp('2009-12-01 12:20:00'),
#   'Price': 6.75,
#   'Customer ID': 14341.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489544,
#   'StockCode': 21809,
#   'Description': 'CHRISTMAS HANGING TREE WITH BELL',
#   'Quantity': 12,
#   'InvoiceDate': Timestamp('2009-12-01 12:20:00'),
#   'Price': 1.25,
#   'Customer ID': 14341.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 90062,
#   'Description': 'CARNIVAL BRACELET',
#   'Quantity': 1,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 12.75,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 21480,
#   'Description': 'PINK STRIPE HOT WATER BOTTLE',
#   'Quantity': 2,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 2.95,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 22110,
#   'Description': 'BIRD HOUSE HOT WATER BOTTLE',
#   'Quantity': 1,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 3.45,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 22113,
#   'Description': 'GREY HEART HOT WATER BOTTLE',
#   'Quantity': 1,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 3.45,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 21484,
#   'Description': 'CHICK GREY HOT WATER BOTTLE',
#   'Quantity': 2,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 3.45,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 20914,
#   'Description': 'SET/5 RED SPOTTY LID GLASS BOWLS',
#   'Quantity': 1,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 2.95,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 84977,
#   'Description': 'WIRE FLOWER T-LIGHT HOLDER',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 1.25,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 21868,
#   'Description': 'POTTING SHED TEA MUG',
#   'Quantity': 1,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 1.25,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 18010,
#   'Description': 'ASSORTED FRAGRANCE BATH CONFETTI',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 0.42,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 21162,
#   'Description': 'TOXIC AREA  DOOR HANGER ',
#   'Quantity': 1,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 1.45,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 37370,
#   'Description': 'RETRO COFFEE MUGS ASSORTED',
#   'Quantity': 2,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 1.25,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 22152,
#   'Description': 'PLACE SETTING WHITE STAR',
#   'Quantity': 15,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 0.42,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 72267,
#   'Description': 'PREMIUM CHURCH CANDLE',
#   'Quantity': 3,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 2.1,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 22139,
#   'Description': 'RETRO SPOT TEA SET CERAMIC 11 PC ',
#   'Quantity': 4,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 4.95,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 22143,
#   'Description': 'CHRISTMAS CRAFT HEART DECORATIONS',
#   'Quantity': 1,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 2.1,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 22197,
#   'Description': 'POPCORN HOLDER , SMALL ',
#   'Quantity': 3,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 0.85,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 22081,
#   'Description': 'RIBBON REEL FLORA + FAUNA ',
#   'Quantity': 1,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 1.65,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 22079,
#   'Description': 'RIBBON REEL HEARTS DESIGN ',
#   'Quantity': 1,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 1.65,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 22273,
#   'Description': 'FELTCRAFT DOLL MOLLY',
#   'Quantity': 1,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 2.95,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 22272,
#   'Description': 'FELTCRAFT DOLL MARIA',
#   'Quantity': 1,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 2.95,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 22274,
#   'Description': 'FELTCRAFT DOLL EMILY',
#   'Quantity': 1,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 2.95,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 21124,
#   'Description': 'SET/10 BLUE SPOTTY PARTY CANDLES',
#   'Quantity': 1,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 1.25,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 21122,
#   'Description': 'SET/10 PINK SPOTTY PARTY CANDLES',
#   'Quantity': 1,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 1.25,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 20758,
#   'Description': 'ABSTRACT CIRCLES POCKET BOOK',
#   'Quantity': 3,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 0.85,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 20756,
#   'Description': 'GREEN FERN POCKET BOOK',
#   'Quantity': 3,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 0.85,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 21126,
#   'Description': 'SET OF 6 GIRLS CELEBRATION CANDLES',
#   'Quantity': 1,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 1.25,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 21125,
#   'Description': 'SET 6 FOOTBALL CELEBRATION CANDLES',
#   'Quantity': 1,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 1.25,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 22154,
#   'Description': 'ANGEL DECORATION 3 BUTTONS ',
#   'Quantity': 8,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 0.42,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 22102,
#   'Description': 'MIRROR MOSAIC T-LIGHT HOLDER ',
#   'Quantity': 3,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 1.65,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 35955,
#   'Description': 'SMALL FOLKART CHRISTMAS TREE DEC',
#   'Quantity': 4,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 0.42,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 35954,
#   'Description': 'SMALL FOLKART STAR CHRISTMAS DEC',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 0.42,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  {'Invoice': 489545,
#   'StockCode': 35957,
#   'Description': 'SMALLFOLKART BAUBLE CHRISTMAS DEC',
#   'Quantity': 6,
#   'InvoiceDate': Timestamp('2009-12-01 12:22:00'),
#   'Price': 0.42,
#   'Customer ID': 17804.0,
#   'Country': 'United Kingdom'},
#  ...]

# %%
DB_NAME= "UNDERSTAND_CUSTOMER"
COLLECTION_NAME= "customer_data"
CONNECTION_URL = "mongodb+srv://dhiraj_pakhrin007:dpakhrin123@cluster0.mbr8lpc.mongodb.net/?appName=Cluster0"

# %%
import pymongo

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

rec = collection.insert_many(data)

# %%
records = collection.find()
records

# %%
df = pd.DataFrame(list(records))
df.head()
# Out:
#                         _id Invoice StockCode  \
# 0  692cde928bfa111b74715156  489434     85048
# 1  692cde928bfa111b74715157  489434    79323P
# 2  692cde928bfa111b74715158  489434    79323W
# 3  692cde928bfa111b74715159  489434     22041
# 4  692cde928bfa111b7471515a  489434     21232
#
#                            Description  Quantity         InvoiceDate  Price  \
# 0  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12 2009-12-01 07:45:00   6.95
# 1                   PINK CHERRY LIGHTS        12 2009-12-01 07:45:00   6.75
# 2                  WHITE CHERRY LIGHTS        12 2009-12-01 07:45:00   6.75
# 3         RECORD FRAME 7" SINGLE SIZE         48 2009-12-01 07:45:00   2.10
# 4       STRAWBERRY CERAMIC TRINKET BOX        24 2009-12-01 07:45:00   1.25
#
#    Customer ID         Country
# 0      13085.0  United Kingdom
# 1      13085.0  United Kingdom
# 2      13085.0  United Kingdom
# 3      13085.0  United Kingdom
# 4      13085.0  United Kingdom
